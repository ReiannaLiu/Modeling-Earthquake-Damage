# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# !pip install imbalanced-learn
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X_train = pd.read_csv('/Users/apple/Desktop/Modeling-Earthquake-Damage/Modeling-Earthquake-Damage/Resources/Datasets/X_train_processed.csv', header = None)
X_test = pd.read_csv('/Users/apple/Desktop/Modeling-Earthquake-Damage/Modeling-Earthquake-Damage/Resources/Datasets/X_test_processed.csv', header = None)
y_train = pd.read_csv('/Users/apple/Desktop/Modeling-Earthquake-Damage/Modeling-Earthquake-Damage/Resources/Datasets/y_train_processed.csv', index_col='building_id')
y_test = pd.read_csv('/Users/apple/Desktop/Modeling-Earthquake-Damage/Modeling-Earthquake-Damage/Resources/Datasets/y_test_processed.csv', index_col='building_id')

y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %%
X_train
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.747082 -0.431751  0.378133  0.220872  0.232501  0.442089 -1.373493
# 1      -0.026492 -1.551366  0.273038 -1.169424  1.046536  0.566434  0.504650
# 2       1.499628  0.526572  2.644983  2.924317  6.146281 -0.449825  0.059980
# 3      -0.445425  1.183950  0.754918 -0.868256  0.046806 -0.988437 -1.000963
# 4       0.269122  0.897501 -0.740030 -0.483209 -0.050316  0.012389  0.717192
# ...          ...       ...       ...       ...       ...       ...       ...
# 208475 -1.351268 -0.902486  0.229352 -1.253266  1.158534  0.798310  0.708510
# 208476 -0.555426 -0.056558 -0.386576 -0.374708 -0.002716 -1.671544  0.682389
# 208477  1.930035  2.455932  0.582061 -1.135528  0.240406  0.635903 -0.330672
# 208478  0.767665  0.223035  0.476524 -1.291648  0.725951  0.873417 -0.403734
# 208479  0.346778 -0.200893 -0.231899 -1.282722  0.570083 -0.398285  1.931468
#
# ...

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)
X_train_smote, y_train_smote
# Out:
#               0         1          2         3         4         5         6   \
# 0       0.747082 -0.431751   0.378133  0.220872  0.232501  0.442089 -1.373493
# 1      -0.026492 -1.551366   0.273038 -1.169424  1.046536  0.566434  0.504650
# 2       1.499628  0.526572   2.644983  2.924317  6.146281 -0.449825  0.059980
# 3      -0.445425  1.183950   0.754918 -0.868256  0.046806 -0.988437 -1.000963
# 4       0.269122  0.897501  -0.740030 -0.483209 -0.050316  0.012389  0.717192
# ...          ...       ...        ...       ...       ...       ...       ...
# 355816 -2.353202 -0.372235   0.321077 -2.144683 -1.007214  0.665646 -1.239631
# 355817  1.102842 -1.647003  10.694568  2.437147 -5.280420  1.016772  4.435475
# 355818 -1.281433 -0.314601   0.436906  0.977434  2.385441  0.604965  1.216762
# 355819  0.794161 -0.095784   0.545868 -0.264700  0.087781 -0.660358 -1.306666
# 355820  1.237294 -0.705111  -0.656235  0.455000 -0.153388 -0.119298  0.102123
#
# ...

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 1.7 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 3.6 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 10.5 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.22.4 which is incompatible.
# ...
